# %% [markdown]
# **Sharvaree Shekhar Bamane. TASK 3**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df= pd.read_csv('/content/Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
plt.hist(df['SepalLengthCm'],edgecolor='black')
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['SepalLengthCm'],edgecolor='black', color ="cyan")
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['PetalWidthCm'],edgecolor='black')
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['PetalWidthCm'],edgecolor='black', color='purple')
# Out:
# (array([41.,  8.,  1.,  7.,  8., 33.,  6., 23.,  9., 14.]),
#  array([0.1 , 0.34, 0.58, 0.82, 1.06, 1.3 , 1.54, 1.78, 2.02, 2.26, 2.5 ]),
#  <BarContainer object of 10 artists>)

# %%
hist = df.hist(bins=9)

# %%
df.groupby('PetalLengthCm').sum()['SepalLengthCm'].plot(kind='bar',figsize=(6,6),color='#CC6C68')
plt.show()
# Out:
# <ipython-input-15-5da8167050af>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('PetalLengthCm').sum()['SepalLengthCm'].plot(kind='bar',figsize=(6,6),color='#CC6C68')

# %%
df.groupby('PetalWidthCm').sum()['SepalLengthCm'].plot(kind='bar',figsize=(6,6),color='#993935')
plt.show()
# Out:
# <ipython-input-14-a6364f331b9c>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('PetalWidthCm').sum()['SepalLengthCm'].plot(kind='bar',figsize=(6,6),color='#993935')

# %%
df.groupby('Species').mean().plot(kind='bar',figsize=(7,7))
plt.show()

# %%
exclude = ['Id']
df[df.columns.difference(exclude)].hist()
plt.figure(figsize=(15,10))
plt.show()
